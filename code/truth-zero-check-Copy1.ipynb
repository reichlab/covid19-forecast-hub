# %%
from utils._utils import *

# %%
import pandas as pd
import numpy as np

# %%
root = get_root()

# %% [markdown]
# # New zoltar truth data

# %%
truth = pd.read_csv(open(root/'data-truth'/'zoltar-truth.csv', 'r'), parse_dates=['timezero'])

# %%
truth[(truth['target'] == '20 wk ahead inc death') & (truth['value'] == 0.0)].sort_values('timezero')
# Out:
#          timezero unit                 target  value
# 153277 2020-04-18   60  20 wk ahead inc death    0.0
# 153306 2020-04-18   33  20 wk ahead inc death    0.0
# 153312 2020-04-18   69  20 wk ahead inc death    0.0
# 153325 2020-04-18   50  20 wk ahead inc death    0.0
# 154417 2020-04-25   60  20 wk ahead inc death    0.0
# 154452 2020-04-25   69  20 wk ahead inc death    0.0
# 154465 2020-04-25   50  20 wk ahead inc death    0.0
# 154471 2020-04-25   56  20 wk ahead inc death    0.0
# 155605 2020-05-02   50  20 wk ahead inc death    0.0
# 155606 2020-05-02   78  20 wk ahead inc death    0.0
# 155557 2020-05-02   60  20 wk ahead inc death    0.0
# 155592 2020-05-02   69  20 wk ahead inc death    0.0
# 156697 2020-05-09   60  20 wk ahead inc death    0.0
# 156732 2020-05-09   69  20 wk ahead inc death    0.0
# 156745 2020-05-09   50  20 wk ahead inc death    0.0
# 156746 2020-05-09   78  20 wk ahead inc death    0.0
# 157837 2020-05-16   60  20 wk ahead inc death    0.0
# ...

# %% [markdown]
# # Old Zoltar Truth data

# %%
truth_old = pd.read_csv(open(root/'data-truth'/'zoltar-truth-1.csv', 'r'), parse_dates=['timezero'])

# %%
pd.set_option('display.max_rows', None)
truth_old[(truth_old['target'] == '20 wk ahead inc death') & (truth_old['value'] == 0.0)].sort_values('timezero')
# Out:
#          timezero   unit                 target  value
# 170768 2019-12-30     56  20 wk ahead inc death    0.0
# 170762 2019-12-30     50  20 wk ahead inc death    0.0
# 170749 2019-12-30     69  20 wk ahead inc death    0.0
# 170740 2019-12-30     30  20 wk ahead inc death    0.0
# 170725 2019-12-30     15  20 wk ahead inc death    0.0
# 170724 2019-12-30     66  20 wk ahead inc death    0.0
# 170714 2019-12-30     60  20 wk ahead inc death    0.0
# 170713 2019-12-30     02  20 wk ahead inc death    0.0
# 320844 2020-01-06     78  20 wk ahead inc death    0.0
# 320830 2020-01-06     69  20 wk ahead inc death    0.0
# 320806 2020-01-06     15  20 wk ahead inc death    0.0
# 320794 2020-01-06     02  20 wk ahead inc death    0.0
# 320821 2020-01-06     30  20 wk ahead inc death    0.0
# 320795 2020-01-06     60  20 wk ahead inc death    0.0
# 320805 2020-01-06     66  20 wk ahead inc death    0.0
# 310648 2020-01-13     02  20 wk ahead inc death    0.0
# ...
