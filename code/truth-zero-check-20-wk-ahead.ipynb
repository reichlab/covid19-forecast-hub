# %%
from utils._utils import *

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)

# %%
root = get_root()

# %%
truth = pd.read_csv(open(root/'data-truth'/'zoltar-truth.csv', 'r'), parse_dates=['timezero'])

truth[(truth['target'] == '20 wk ahead inc death')].sort_values('timezero', ascending=False)
# Out:
#          timezero unit                 target   value
# 275938 2020-06-15   02  20 wk ahead inc death    14.0
# 275951 2020-06-15   16  20 wk ahead inc death    57.0
# 275964 2020-06-15   29  20 wk ahead inc death   229.0
# 275963 2020-06-15   28  20 wk ahead inc death    79.0
# 275962 2020-06-15   27  20 wk ahead inc death   130.0
# 275961 2020-06-15   26  20 wk ahead inc death   177.0
# 275960 2020-06-15   25  20 wk ahead inc death   152.0
# 275959 2020-06-15   24  20 wk ahead inc death    56.0
# 275958 2020-06-15   23  20 wk ahead inc death     1.0
# 275957 2020-06-15   22  20 wk ahead inc death    99.0
# 275956 2020-06-15   21  20 wk ahead inc death    81.0
# 275955 2020-06-15   20  20 wk ahead inc death    69.0
# 275954 2020-06-15   19  20 wk ahead inc death    82.0
# 275952 2020-06-15   17  20 wk ahead inc death   289.0
# 275950 2020-06-15   15  20 wk ahead inc death     7.0
# 275966 2020-06-15   31  20 wk ahead inc death    57.0
# ...

# %% [markdown]
# # Old truth data

# %%
truth = pd.read_csv(open(root/'data-truth'/'zoltar-truth copy.csv', 'r'), parse_dates=['timezero'])

truth[(truth['target'] == '20 wk ahead inc death')].sort_values('timezero', ascending=False)
# Out:
#          timezero unit                 target    value
# 364515 2020-12-21   01  20 wk ahead inc death    102.0
# 364558 2020-12-21   44  20 wk ahead inc death    104.0
# 364545 2020-12-21   32  20 wk ahead inc death     58.0
# 364546 2020-12-21   33  20 wk ahead inc death     47.0
# 364547 2020-12-21   34  20 wk ahead inc death   1503.0
# 364548 2020-12-21   35  20 wk ahead inc death     53.0
# 364549 2020-12-21   36  20 wk ahead inc death   2253.0
# 364550 2020-12-21   37  20 wk ahead inc death    120.0
# 364551 2020-12-21   38  20 wk ahead inc death     11.0
# 364552 2020-12-21   69  20 wk ahead inc death      0.0
# 364553 2020-12-21   39  20 wk ahead inc death    309.0
# 364554 2020-12-21   40  20 wk ahead inc death     32.0
# 364555 2020-12-21   41  20 wk ahead inc death     18.0
# 364556 2020-12-21   42  20 wk ahead inc death   1084.0
# 364559 2020-12-21   45  20 wk ahead inc death     63.0
# 364543 2020-12-21   30  20 wk ahead inc death      0.0
# ...
